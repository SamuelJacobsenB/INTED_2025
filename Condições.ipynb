# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelJacobsenB/INTED_2025/blob/main/Condi%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Digite um número: "))
print("Maior que 10" if num > 10 else "")
# Out:
# Digite um número20
# Maior que 10

# %%
num = int(input("Digite um número: "))
print("É par" if num % 2 == 0 else "")
# Out:
# Digite um número: 8
# É par

# %%
text = input("Digite um texto: ")
print("Tem a letra 'a'" if 'a' in text else "")
# Out:
# Digite um texto: ola
# Tem a letra 'a'

# %%
num = int(input("Digite um número: "))
print("É múltiplo de 5" if num % 5 == 0 else "")
# Out:
# Digite um número: 10
# É múltiplo de 5

# %%
num = int(input("Digite um número: "))
print("Está quente" if num > 30 else "Está frio")
# Out:
# Digite um número: 40
# Está quente

# %%
while True:
  text = input("Digite S (continuar) ou N (terminar): ").lower()
  if text == 's':
    print("Continuando...")
  elif text == 'n':
    print("Terminando...")
    break
# Out:
# Digite S (continuar) ou N (terminar): S
# Continuando...
# Digite S (continuar) ou N (terminar): n
# Terminando...

# %%
num = int(input("Digite um número: "))
if num == 0:
  print("Igual a zero")
elif num > 0:
  print("Positivo")
else:
  print("Negativo")
# Out:
# Digite um número: 5
# Número maior que 0

# %%
num = int(input("Digite um número: "))
if num == 1:
  print("Domingo")
elif num == 2:
  print("Segunda")
elif num ==3:
  print("Terça")
elif num == 4:
  print("Quarta")
elif num == 5:
  print("Quinta")
elif num == 6:
  print("Sexta")
else:
  print("Sábado")
# Out:
# Digite um número: 5
# Quinta

# %%
num = int(input("Digite um número: "))
print("É bissexto" if num % 4 == 0 else "")
# Out:
# Digite um número: 2024
# É bissexto

# %%
hours = int(input("Digite número de horas: "))
perHour = int(input("Digite número de por hora: "))
if hours < 40:
  print("Salário é: R$", hours * perHour * 1.5)
else:
  print("Salário é: R$", hours * perHour)
# Out:
# Digite número de horas: 50
# Digite número de por hora: 5
# Salário é: R$  250
